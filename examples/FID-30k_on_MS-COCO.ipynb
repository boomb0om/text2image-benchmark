# %%
import sys
sys.path.append('../')
from T2IBenchmark import calculate_fid
from T2IBenchmark.datasets import get_coco_fid_stats

# %% [markdown]
# **Calculate FID between dummy images and MS-COCO validation**

# %%
fid, _ = calculate_fid(
    '../assets/images/cats/',
    get_coco_fid_stats()
)
# Out:
# Processing: ImageDataset(5 items)
# 100%|██████████| 1/1 [00:03<00:00,  3.34s/it]
# Processing: <T2IBenchmark.metrics.fid.FIDStats object at 0x7f91a01ae350>
# FID is 338.15181212283085

# %% [markdown]
# **Calculate FID between model generations and MS-COCO validation**
#
# Generations should be generated by 30000 prompts which you can get using `get_coco_30k_captions()`

# %%
from T2IBenchmark.datasets import get_coco_30k_captions

imageid2caption = get_coco_30k_captions()
print(len(imageid2caption))
# Out:
# 30000

# %%
fid, _ = calculate_fid(
    'path/to/your/generations/',
    get_coco_fid_stats()
)
